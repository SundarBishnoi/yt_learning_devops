# %%
import sys
print(f"Python Version: {sys.version}")
print("Success! Hardware is running flawlessly.")
# Out:
# Python Version: 3.14.4 (main, Apr  8 2026, 04:02:31) [GCC 15.2.0]
# Success! Hardware is running flawlessly.
