# %% [markdown]
# Write a script to report the usage of AWS in your project??

# %% [markdown]
# Why would somebody move to cloud infrastructure?
# Primary reason for someone to move to cloud.
# 1. Manageability as there is lot of maintenance overhead in on-prem infrastructure(eg. you have to create your own DC, manage your own server, you have to keep patching them whenever there is security issue, contantly upgrade those server, dedicately System Admins are reuired to keep and manage them up)
# 2. Cost - These cloud provider works on simple basis, pay as you go. When you move to cloud if you are not using certain instances, you will not be billed for it.. whereas if you are buying your physical infrastructure for your company, whether you use it or not, you would already have it in your datacenter so you have to pay for it.
#
# One of your primary responsibilities as devops eng, is to maintain cost effectiveness by tracking resource usage.
# Let's say, we are using services in our org - ec2 instance, s3, lambda, IAM. i can create shell/python script and use cronjob to run this script automatically at certain time.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Problem statement: Day to day, in our project. contributor of project keeps on updating. so whether the user is joining new, or leaving the project. This project would require
